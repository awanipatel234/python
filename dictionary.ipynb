# %%
countries = {
    "INdia":"New  Delhi",
    "USA":"Washington",
    "France":"Paris",
    "Germany":"Berlin",
    "Italy":"Rome"
     
}
print(countries)
# Out:
# {'INdia': 'New  Delhi', 'USA': 'Washington', 'France': 'Paris', 'Germany': 'Berlin', 'Italy': 'Rome'}

# %%
countries = {"India":"New  Delhi"}
print(countries["India"])
# Out:
# New  Delhi

# %%
countries = {"India":"New Delhi", "USA":"Washington"}
countries["USA"]="NEW YORK"
print(countries)
# Out:
# {'India': 'New Delhi', 'USA': 'NEW YORK'}

# %%
countries = {
    "India":"New Delhi",
    "France":"Paris"
}
del countries["France"]
print(countries)
# Out:
# {'India': 'New Delhi'}

# %%
students = {
    "Rahul":85,
    "Anita":92,
    "Sunil":78,
}
print(students.values())
# Out:
# dict_values([85, 92, 78])
