# %%
with open(r"C:\Users\HP-PC\OneDrive\Documents\student.txt") as file:
    content = file.read()
    print(content)
# Out:
# awani,20,pune
#
# Sneha, 22, Mumbai
# Rohan, 20, Bangalore

# %%
with open(r"C:\Users\HP-PC\OneDrive\Documents\student.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# awani,20,pune
#
# Sneha, 22, Mumbai
# Rohan, 20, Bangalore

# %%
with open(r"C:\Users\HP-PC\OneDrive\Documents\file_handling2.txt","r") as file:
    content = file.read()
    print(content)
# Out:
# P101, Laptop, 55000, Electronics
# P102, Mouse, 800, Electronics
# P103, Chair, 3000, Furniture
# P104, Table, 7000, Furniture
# P105, Mobile, 25000, Electronics

# %%
with open(r"C:\Users\HP-PC\OneDrive\Documents\file_handling2.txt", "r") as file:
    
    print(file.readlines())
# Out:
# ['P101, Laptop, 55000, Electronics\n', 'P102, Mouse, 800, Electronics\n', 'P103, Chair, 3000, Furniture\n', 'P104, Table, 7000, Furniture\n', 'P105, Mobile, 25000, Electronics']

# %%
with open(r"C:\Users\HP-PC\OneDrive\Documents\file_handling2.txt", "r") as file:
    lines = file.readlines()
    print(lines)
# Out:
# ['P101, Laptop, 55000, Electronics\n', 'P102, Mouse, 800, Electronics\n', 'P103, Chair, 3000, Furniture\n', 'P104, Table, 7000, Furniture\n', 'P105, Mobile, 25000, Electronics']

# %%
with open(r"C:\Users\HP-PC\OneDrive\Documents\file_handling2.txt", "r") as file:
    for line in file:
        print(line)
# Out:
# P101, Laptop, 55000, Electronics
#
# P102, Mouse, 800, Electronics
#
# P103, Chair, 3000, Furniture
#
# P104, Table, 7000, Furniture
#
# P105, Mobile, 25000, Electronics

# %%
with open(r"C:\Users\HP-PC\OneDrive\Documents\file_handling2.txt", "r") as file:
    for line in file:
        data = line.strip().split(',')
        
        print(data[1])
# Out:
#  Laptop
#  Mouse
#  Chair
#  Table
#  Mobile

# %%
with open(r"C:\Users\HP-PC\OneDrive\Documents\file_handling2.txt", "r") as file:
    for line in file:
        data = line.strip().split(',')
        price = int(data[2])   # price
        if price > 1000:
            print(line)
# Out:
# P101, Laptop, 55000, Electronics
#
# P103, Chair, 3000, Furniture
#
# P104, Table, 7000, Furniture
#
# P105, Mobile, 25000, Electronics
