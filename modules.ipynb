# %%
import math
print(math.sqrt(625))
# Out:
# 25.0

# %%
import math
print(math.factorial(6))
# Out:
# 720

# %%
import math
print(math.floor(4.7))
print(math.ceil(4.7))
# Out:
# 4
# 5

# %%
import math
print(math.pow(5,3))
# Out:
# 125.0

# %%
import math
print(math.fabs(-18))
# Out:
# 18.0

# %%
import math
rad = math.radians(90)
print(math.sin(rad))
print(math.cos(rad))
print(math.tan(rad))
# Out:
# 1.0
# 6.123233995736766e-17
# 1.633123935319537e+16

# %%
import math
print(math.gcd(36,60))
# Out:
# 12

# %%
import math
print(math.exp(3))
# Out:
# 20.085536923187668

# %%
import math
print(math.log10(1000))
# Out:
# 3.0

# %%
import math
print(math.radians(180))
# Out:
# 3.141592653589793

# %%
import random

# %%
print(random.randint(1,10))
# Out:
# 8

# %%
print(random.random)
# Out:
# <built-in method random of Random object at 0x000002C400C3C510>

# %%
lst = [10,20,30,40,50]
print(random.choice(lst))
# Out:
# 40

# %%
lst = [1,2,3,4,5]
random.shuffle(lst)
print(lst)
# Out:
# [1, 3, 4, 5, 2]

# %%
print(random.randrange(2,21,2))
# Out:
# 4

# %%
for i in range(5):
    print(random.randint(10,100))
# Out:
# 79
# 19
# 98
# 31
# 16

# %%
print(random.randint(1,6))
# Out:
# 2

# %%
fruits=['apple', 'banana', 'cherry', 'mango', 'orange']
print(random.sample(fruits, 3))
# Out:
# ['apple', 'mango', 'cherry']

# %%
import random
import string
password = ''.join(random.choice(string.ascii_lowercase) for i in range(8))
print(password)
# Out:
# cdnzqimw

# %%
print(random.sample(range(1,21),4))
# Out:
# [6, 1, 9, 10]
